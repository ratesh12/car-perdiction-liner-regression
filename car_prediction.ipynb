# %% [markdown]
# # Step1 Import Necessary Libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Step2:Load dataset

# %%
data=pd.read_csv("rishu.csv")
data
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %% [markdown]
# # Step 3: Data Analysis/Data Handling/Data Modififcation/Data Cleaning

# %%
data=data.drop(columns=["CarName","fueltype","aspiration","doornumber","carbody","drivewheel","enginelocation","fuelsystem","enginetype","cylindernumber"		])
data
# Out:
#      car_ID  symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0         1          3       88.6      168.8      64.1       48.8        2548
# 1         2          3       88.6      168.8      64.1       48.8        2548
# 2         3          1       94.5      171.2      65.5       52.4        2823
# 3         4          2       99.8      176.6      66.2       54.3        2337
# 4         5          2       99.4      176.6      66.4       54.3        2824
# ..      ...        ...        ...        ...       ...        ...         ...
# 200     201         -1      109.1      188.8      68.9       55.5        2952
# 201     202         -1      109.1      188.8      68.8       55.5        3049
# 202     203         -1      109.1      188.8      68.9       55.5        3012
# 203     204         -1      109.1      188.8      68.9       55.5        3217
# 204     205         -1      109.1      188.8      68.9       55.5        3062
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   wheelbase         205 non-null    float64
#  3   carlength         205 non-null    float64
#  4   carwidth          205 non-null    float64
#  5   carheight         205 non-null    float64
#  6   curbweight        205 non-null    int64
#  7   enginesize        205 non-null    int64
#  8   boreratio         205 non-null    float64
#  9   stroke            205 non-null    float64
#  10  compressionratio  205 non-null    float64
#  11  horsepower        205 non-null    int64
#  12  peakrpm           205 non-null    int64
#  13  citympg           205 non-null    int64
#  14  highwaympg        205 non-null    int64
#  15  price             205 non-null    float64
# ...

# %% [markdown]
# # Step 4: Seperate input and output in different variables

# %%
x=data.iloc[:,0:15]
x
# Out:
#      car_ID  symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0         1          3       88.6      168.8      64.1       48.8        2548
# 1         2          3       88.6      168.8      64.1       48.8        2548
# 2         3          1       94.5      171.2      65.5       52.4        2823
# 3         4          2       99.8      176.6      66.2       54.3        2337
# 4         5          2       99.4      176.6      66.4       54.3        2824
# ..      ...        ...        ...        ...       ...        ...         ...
# 200     201         -1      109.1      188.8      68.9       55.5        2952
# 201     202         -1      109.1      188.8      68.8       55.5        3049
# 202     203         -1      109.1      188.8      68.9       55.5        3012
# 203     204         -1      109.1      188.8      68.9       55.5        3217
# 204     205         -1      109.1      188.8      68.9       55.5        3062
#
# ...

# %%
y=data.iloc[:,-1]
y
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 205, dtype: float64

# %% [markdown]
# # Step 5:Split input output data in training and testing

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size= 0.2,random_state = 42)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 164 entries, 66 to 102
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            164 non-null    int64
#  1   symboling         164 non-null    int64
#  2   wheelbase         164 non-null    float64
#  3   carlength         164 non-null    float64
#  4   carwidth          164 non-null    float64
#  5   carheight         164 non-null    float64
#  6   curbweight        164 non-null    int64
#  7   enginesize        164 non-null    int64
#  8   boreratio         164 non-null    float64
#  9   stroke            164 non-null    float64
#  10  compressionratio  164 non-null    float64
#  11  horsepower        164 non-null    int64
#  12  peakrpm           164 non-null    int64
#  13  citympg           164 non-null    int64
#  14  highwaympg        164 non-null    int64
# dtypes: float64(7), int64(8)
# memory usage: 20.5 KB

# %%
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41 entries, 15 to 146
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            41 non-null     int64
#  1   symboling         41 non-null     int64
#  2   wheelbase         41 non-null     float64
#  3   carlength         41 non-null     float64
#  4   carwidth          41 non-null     float64
#  5   carheight         41 non-null     float64
#  6   curbweight        41 non-null     int64
#  7   enginesize        41 non-null     int64
#  8   boreratio         41 non-null     float64
#  9   stroke            41 non-null     float64
#  10  compressionratio  41 non-null     float64
#  11  horsepower        41 non-null     int64
#  12  peakrpm           41 non-null     int64
#  13  citympg           41 non-null     int64
#  14  highwaympg        41 non-null     int64
# dtypes: float64(7), int64(8)
# memory usage: 5.1 KB

# %%
y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 164 entries, 66 to 102
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 164 non-null    float64
# dtypes: float64(1)
# memory usage: 2.6 KB

# %%
y_test.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 41 entries, 15 to 146
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 41 non-null     float64
# dtypes: float64(1)
# memory usage: 656.0 bytes

# %% [markdown]
# # Step 5: Import Algorithm

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %% [markdown]
# # Step 6: Model Train(.fit()) and Prediction(.predict())

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Step 7:Predict  Use for predection

# %%
y_pred=lr.predict(x_test)

# %% [markdown]
# # Prediction

# %%
data.head(2)
# Out:
#    car_ID  symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0       1          3       88.6      168.8      64.1       48.8        2548
# 1       2          3       88.6      168.8      64.1       48.8        2548
#
#    enginesize  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# 0         130       3.47    2.68               9.0         111     5000
# 1         130       3.47    2.68               9.0         111     5000
#
#    citympg  highwaympg    price
# 0       21          27  13495.0
# 1       21          27  16500.0

# %%
bo=lr.coef_
b0=lr.intercept_
b0
y=(-1.27853011e+02*3)+(1.16514484e+02*88.6)+(-5.40264470e+01*168.8)+(4.78025906e+02*64.1)+(2.53140985e+02*48.8)+(6.70444781e-01*2548)+(1.12926062e+02*130)+(5.10829093e+02*3.47)+(-3.26761194e+03*2.68)+(3.59638834e+02*9.0)+(2.88913873e+01*111)+( 2.30396478e+00*5000)+(-3.90406107e+02*21)+(2.09742807e+02*27)+b0
y
# Out:
# np.float64(13575.186305413292)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.851665712636321

# %%
joblib.dump(lr,"car prediction.joblib")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 joblib.dump(lr,"car prediction.joblib")
#
# NameError: name 'joblib' is not defined
